# %% [markdown]
# This notebook is for using linear regression to predict housing prices across the U.S.

# %% [markdown]
# #### Import necessary libraries
# We will be exploring various regression models using:
# - Python
# - Scikit-Learn
# - Seaborn
# - Matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import the dataset

# %% [markdown]
# ### Explore the dataset

# %% [markdown]
# ### Visualize data

# %% [markdown]
# ## Regression models
# Now that we have a good idea of what data we are working with, it's time to generate some models.

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# ### Multiple linear regression

# %% [markdown]
# ### Polynomial regression

# %% [markdown]
# ### Random sample consensus (RANSAC)

# %% [markdown]
# ### Ridge regression

# %% [markdown]
# ### Lasso regression

# %% [markdown]
# ### Elastic-net regression

# %% [markdown]
# ### Random forest regression
